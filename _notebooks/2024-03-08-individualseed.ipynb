# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: Individual Seed Tri Three
# courses: { csa: {week: 25} }
# ---

# %% [markdown]
# <h2> Requirements for Seed </h2>
#
# <img width="622" alt="Screen Shot 2024-03-08 at 8 54 10 AM" src="https://github.com/Ekamjot-Kaire/student/assets/111466888/f41aa920-bf7f-4141-a90b-4d412ffed819">
#
#
# <br>
# <r>
#
# My grade was < 93%, so I only qualify for 90% seed:
#
# * **Exemplar in Team work.  Fosters community of learning beyond individual or single friend:**
#
# I have been contributing to our team with my own feature. This feature was worked on with 2-3 other people (Drew and AJ). Throughout the period we talked with each other and offered ideas to get our JWTs to send. This feature was difficult since we were facing many issues, especially with CORS and the creation of JSON objects, so a lot of collaboration was needed to make it happen.
#
# Code comments show communication between team members:
#
# <img width="885" alt="Screen Shot 2024-03-08 at 8 57 53 AM" src="https://github.com/Ekamjot-Kaire/student/assets/111466888/b83532cb-de1d-44b7-a431-86417e8e6c68">
#
# <img width="788" alt="Screen Shot 2024-03-08 at 8 58 07 AM" src="https://github.com/Ekamjot-Kaire/student/assets/111466888/2be811c7-f891-4e9b-bbff-6761bf37babb">
#
#
# * **Individual Progress.  Individual maintains an at-a-glance.  AP preparation progress, Key commits, GitHub Analytics, etc.  They use this blog to start each individual review.**
#
# > GitHub Pages Blog.  Student makes quality effort to record histories and solicit comments on AP, Project work:
#
# Blog is used to lay out goals and work done within the week:
#
# <img width="860" alt="Screen Shot 2024-03-08 at 9 01 42 AM" src="https://github.com/Ekamjot-Kaire/student/assets/111466888/22ea5ffb-9d48-4823-85c4-7f41a3bd3bab">
#
# <br>
# <br>
#
# > AP work.  All AP work is understood, reviewed, and is determined by Teacher to be your own work.  Student should be proactive in demonstrating understanding.
#
# For AP preparation, I had come up with plans to better implement CollegeBoard concepts into our project through the 2015 FRQ review. Although my current role in the team is to create wireframes, when working more on backend later in the trimester I will bring up these ideas during team meetings to possible implement.
#
# [issue](https://github.com/Ekamjot-Kaire/student/issues/10)
#
# <br>
# <br>
#
# > Project work.  Student follows team requirements and expectations.  They are active in the Scrum work and timelines.
#
#
# Key Commits from last Trimester:
#
# [person object work](https://github.com/John-sCC/jcc_backend/commit/e6f44538b1939f25f806d0f3a112fe6a775cd8a4)
# [login page fetch sent](https://github.com/John-sCC/jcc_frontend/commit/704ac689325a28b44e0b7a96b912ad51b3f78efa)
# [added UI](https://github.com/John-sCC/jcc_frontend/commit/b21588a43af7a20b5b999a1685de09874a5720a4)
#
# Analytics:
#
# <img width="1199" alt="Screen Shot 2024-03-08 at 9 08 25 AM" src="https://github.com/Ekamjot-Kaire/student/assets/111466888/4a58a0b8-381b-4405-99f1-9008c4034104">
